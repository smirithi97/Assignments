# %%
university_system = {
    "universities": {
        "GTU_India": {
            "location": "Chennai",
            "ranking": 5,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Narayan",
                    "departments": {
                        "computer_science": {
                            "hod": "Dr. Anish",
                            "labs": {
                                "AI Lab": {
                                    "incharge": "Dr. Meera",
                                    "research_projects": {
                                        "DeepVision": {
                                            "funding": 250000,
                                            "researchers": ["Arjun", "Sneha"],
                                            "status": "ongoing"
                                        },
                                        "RoboMind": {
                                            "funding": 180000,
                                            "researchers": ["Ishita", "Rahul"],
                                            "status": "completed"
                                        }
                                    }
                                },
                                "Systems Lab": {
                                    "incharge": "Dr. Raman",
                                    "research_projects": {
                                        "CloudScale": {
                                            "funding": 300000,
                                            "researchers": ["Karan", "Neha"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            },
                            "courses": {
                                "Data Structures": {
                                    "credits": 4,
                                    "students_enrolled": 120
                                },
                                "Machine Learning": {
                                    "credits": 3,
                                    "students_enrolled": 90
                                }
                            }
                        }
                    }
                },
                "management": {
                    "dean": "Dr. Kapoor",
                    "departments": {
                        "finance": {
                            "hod": "Dr. Iyer",
                            "courses": {
                                "Corporate Finance": {
                                    "credits": 3,
                                    "students_enrolled": 80
                                }
                            }
                        }
                    }
                }
            }
        },
        "GTU_Singapore": {
            "location": "Singapore",
            "ranking": 2,
            "faculties": {
                "engineering": {
                    "dean": "Dr. Lee",
                    "departments": {
                        "robotics": {
                            "hod": "Dr. Tan",
                            "labs": {
                                "Automation Lab": {
                                    "incharge": "Dr. Wong",
                                    "research_projects": {
                                        "AutoNav": {
                                            "funding": 400000,
                                            "researchers": ["Jason", "Lily"],
                                            "status": "ongoing"
                                        }
                                    }
                                }
                            }
                        }
                    }
                }
            }
        }
    }
}

# %% [raw]
# Questions to improve your understanding of dictionary
#
#
# 1.	Print the location of GTU_India.
# 2.	Print the dean of the engineering faculty in GTU_Singapore.
# 3.	Print the HOD of the computer_science department.
# 4.	Print all labs under computer_science.
# 5.	Print the funding amount of the "DeepVision" project.
# 6.	Print all research project names in GTU_India.
# 7.	Print all ongoing projects in GTU_India.
# 8.	Calculate the total funding for all projects in AI Lab.
# 9.	Print all researchers working under Systems Lab.
# 10.	Count total students enrolled in all computer_science courses.
# 11.	Print all university names in the system.
# 12.	Print all faculty names under GTU_India.
# 13.	Print all department names across all universities.
# 14.	Print all deans in the entire system.
# 15.	Print all project names across both universities.
# 16.	Add a new research project under AI Lab.
# 17.	Change the status of "DeepVision" to completed.
# 18.	Increase funding of "CloudScale" by 50,000.
# 19.	Add a new university to the system.
# 20.	Add a new course under finance department.
# 21.	Find the project with the highest funding.
# 22.	Find total funding across all universities.
# 23.	Find the university with the best ranking.
# 24.	Print all completed projects.
# 25.	Count total number of researchers in GTU_India.
# 26.	Find which lab has the maximum funding.
# 27.	Print projects grouped by status (ongoing/completed).
# 28.	Print all courses with more than 100 students enrolled.
# 29.	Find total number of faculties in the entire system.
# 30.	Write a function that searches for a project name and prints its full details.

# %%
print("1.",university_system["universities"]["GTU_India"]["location"])
print("2.", university_system["universities"]["GTU_Singapore"]["faculties"]["engineering"]["dean"])
print("3:", university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["hod"])
print("4:", list(university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"].keys()))
print("5:", university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]["AI Lab"]["research_projects"]["DeepVision"]["funding"])

projects_india = []
labs = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["labs"]
for lab in labs.values():
    projects_india.extend(lab["research_projects"].keys())
print("6:", projects_india)

ongoing_projects = []
for lab in labs.values():
    for pname, pdata in lab["research_projects"].items():
        if pdata["status"] == "ongoing":
            ongoing_projects.append(pname)
print("7:", ongoing_projects)


ai_lab = labs["AI Lab"]["research_projects"]
total_funding_ai = sum([proj["funding"] for proj in ai_lab.values()])
print("8:", total_funding_ai)


print("9:", labs["Systems Lab"]["research_projects"]["CloudScale"]["researchers"])


courses = university_system["universities"]["GTU_India"]["faculties"]["engineering"]["departments"]["computer_science"]["courses"]
total_students = sum([c["students_enrolled"] for c in courses.values()])
print("10:", total_students)


print("11:", list(university_system["universities"].keys()))

print("12:", list(university_system["universities"]["GTU_India"]["faculties"].keys()))


departments = []
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        departments.extend(fac["departments"].keys())
print("13:", departments)


deans = []
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        deans.append(fac["dean"])
print("14:", deans)


projects_all = []
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        for dept in fac["departments"].values():
            if "labs" in dept:
                for lab in dept["labs"].values():
                    projects_all.extend(lab["research_projects"].keys())
print("15:", projects_all)

labs["AI Lab"]["research_projects"]["NeuroNet"] = {
    "funding": 200000,
    "researchers": ["Amit", "Priya"],
    "status": "ongoing"
}
print("Q16: Added NeuroNet project")


labs["AI Lab"]["research_projects"]["DeepVision"]["status"] = "completed"
print("17: DeepVision status updated")


labs["Systems Lab"]["research_projects"]["CloudScale"]["funding"] += 50000
print("18: CloudScale funding updated")


university_system["universities"]["GTU_USA"] = {
    "location": "New York",
    "ranking": 3,
    "faculties": {}
}
print("19: Added GTU_USA")


university_system["universities"]["GTU_India"]["faculties"]["management"]["departments"]["finance"]["courses"]["Investment Banking"] = {
    "credits": 4,
    "students_enrolled": 70
}
print("20: Added Investment Banking course")


max_project = None
max_funding = 0
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        for dept in fac["departments"].values():
            if "labs" in dept:
                for lab in dept["labs"].values():
                    for pname, pdata in lab["research_projects"].items():
                        if pdata["funding"] > max_funding:
                            max_funding = pdata["funding"]
                            max_project = pname
print("21:", max_project, "-", max_funding)


total_funding = 0
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        for dept in fac["departments"].values():
            if "labs" in dept:
                for lab in dept["labs"].values():
                    total_funding += sum([proj["funding"] for proj in lab["research_projects"].values()])
print("22:", total_funding)


best_uni = min(university_system["universities"].items(), key=lambda x: x[1]["ranking"])
print("23:", best_uni)


completed_projects = []
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        for dept in fac["departments"].values():
            if "labs" in dept:
                for lab in dept["labs"].values():
                    for pname, pdata in lab["research_projects"].items():
                        if pdata["status"] == "completed":
                            completed_projects.append(pname)
print("24:", completed_projects)

researchers_india = []
for fac in university_system["universities"]["GTU_India"]["faculties"].values():
    for dept in fac["departments"].values():
        if "labs" in dept:
            for lab in dept["labs"].values():
                for proj in lab["research_projects"].values():
                    researchers_india.extend(proj["researchers"])
print("25:", len(researchers_india))


lab_funding = {}
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        for dept in fac["departments"].values():
            if "labs" in dept:
                for lname, lab in dept["labs"].items():
                    lab_funding[lname] = sum([proj["funding"] for proj in lab["research_projects"].values()])
max_lab = max(lab_funding.items(), key=lambda x: x[1])
print("26:", max_lab)


status_groups = {"ongoing": [], "completed": []}
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        for dept in fac["departments"].values():
            if "labs" in dept:
                for lab in dept["labs"].values():
                    for pname, pdata in lab["research_projects"].items():
                        status_groups[pdata["status"]].append(pname)
print("27:", status_groups)


big_courses = []
for uni in university_system["universities"].values():
    for fac in uni["faculties"].values():
        for dept in fac["departments"].values():
            if "courses" in dept:
                for cname, cdata in dept["courses"].items():
                    if cdata["students_enrolled"] > 100:
                        big_courses.append(cname)
print("28:", big_courses)


fac_count = 0
for uni in university_system["universities"].values():
    fac_count += len(uni["faculties"])
print("29:", fac_count)


def search_project(project_name):
    for uni_name, uni in university_system["universities"].items():
        for fac in uni["faculties"].values():
            for dept in fac["departments"].values():
                if "labs" in dept:
                    for lab in dept["labs"].values():
                        if project_name in lab["research_projects"]:
                            print(f"Found in {uni_name} -> {project_name}: {lab['research_projects'][project_name]}")
                            return
    print("Project not found.")
# Out:
# 1. Chennai
# 2. Dr. Lee
# 3: Dr. Anish
# 4: ['AI Lab', 'Systems Lab']
# 5: 250000
# 6: ['DeepVision', 'RoboMind', 'CloudScale']
# 7: ['DeepVision', 'CloudScale']
# 8: 430000
# 9: ['Karan', 'Neha']
# 10: 210
# 11: ['GTU_India', 'GTU_Singapore']
# 12: ['engineering', 'management']
# 13: ['computer_science', 'finance', 'robotics']
# 14: ['Dr. Narayan', 'Dr. Kapoor', 'Dr. Lee']
# 15: ['DeepVision', 'RoboMind', 'CloudScale', 'AutoNav']
# Q16: Added NeuroNet project
# 17: DeepVision status updated
# 18: CloudScale funding updated
# 19: Added GTU_USA
# 20: Added Investment Banking course
# 21: AutoNav - 400000
# 22: 1380000
# 23: ('GTU_Singapore', {'location': 'Singapore', 'ranking': 2, 'faculties': {'engineering': {'dean': 'Dr. Lee', 'departments': {'robotics': {'hod': 'Dr. Tan', 'labs': {'Automation Lab': {'incharge': 'Dr. Wong', 'research_projects': {'AutoNav': {'funding': 400000, 'researchers': ['Jason', 'Lily'], 'status': 'ongoing'}}}}}}}}})
# 24: ['DeepVision', 'RoboMind']
# 25: 8
# ...
